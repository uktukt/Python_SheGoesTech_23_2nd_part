# %% [markdown]
# 1) Select any free API (the choice is up to you, you can use any from https://rapidapi.com/collection/list-of-free-apis).

# %%
import sqlite3

conn = sqlite3.connect('dogs.db')
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE IF NOT EXISTS Breeds (
        id INTEGER PRIMARY KEY,
        breed TEXT,
        origin TEXT
    )
''')


cursor.execute('''
    CREATE TABLE IF NOT EXISTS Breeds_img (
        id INTEGER PRIMARY KEY,
        url TEXT,
        img TEXT
    )
''')

conn.commit()
conn.close()

# %%
import json
import sqlite3
import requests

url = "https://dog-breeds2.p.rapidapi.com/dog_breeds/group/breed_status/extinct"

headers = {
    "X-RapidAPI-Key": "51b07a06c6mshbaae7fd65806f5cp13da34jsn59c5aa35baa7",
    "X-RapidAPI-Host": "dog-breeds2.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
api_data = response.json()

data = api_data

# %%
conn = sqlite3.connect('dogs.db')
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE IF NOT EXISTS Breeds (
        id INTEGER PRIMARY KEY,
        breed TEXT,
        origin TEXT
    )
''')

for record in data:
    cursor.execute('''
        INSERT INTO Breeds (id, breed, origin) VALUES (?, ?, ?)
    ''', (record['id'], record['breed'], record['origin']))

conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\dovil\Desktop\she goes tech\Python_SheGoesTech_23_2nd_part\hw_api_sqlite3.ipynb Cell 4 in 1
#       <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> cursor.execute('''
#       <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>     SELECT Breeds.breed, Breeds.origin, Breeds_img.url, Breeds_img.img
#       <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>     FROM Breeds
#       <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a>     JOIN Breeds_img ON Breeds.id = Breeds_img.id
#       <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> ''')
#      <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> for record in data:
#      <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a>     cursor.execute('''
#      <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a>         INSERT INTO Breeds (id, breed, origin) VALUES (?, ?, ?)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=12'>13</a>     ''', (record['id'], record['breed'], record['origin']))
#      <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a> conn.commit()
#      <a href='vscode-notebook-cell:/c%3A/Users/dovil/Desktop/she%20goes%20tech/Python_SheGoesTech_23_2nd_part/hw_api_sqlite3.ipynb#X14sZmlsZQ%3D%3D?line=15'>16</a> conn.close()
#
# TypeError: tuple indices must be integers or slices, not str

# %%
conn = sqlite3.connect('dogs.db')
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE IF NOT EXISTS Breeds_img (
        id INTEGER PRIMARY KEY,
        url TEXT,
        img TEXT
    )
''')

for record in data:
    cursor.execute('''
        INSERT INTO Breeds_img (id, url, img) VALUES (?, ?, ?)
    ''', (record['id'], record['url'], record['img']))

conn.commit()
conn.close()

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('dogs.db')
cursor = conn.cursor()

cursor.execute('''
    SELECT Breeds.breed, Breeds.origin, Breeds_img.url, Breeds_img.img
    FROM Breeds
    JOIN Breeds_img ON Breeds.id = Breeds_img.id
''')
data = cursor.fetchall()

conn.close()

df = pd.DataFrame(data, columns=['Breed', 'Origin', 'Link', 'Img'])
df.head()
# Out:
#                   Breed                       Origin  \
# 0   Old English Terrier                      England
# 1  African hairless dog                       Africa
# 2                Alaunt        Pontic-Caspian Steppe
# 3        Alpine Mastiff       Swiss and Italian Alps
# 4       Belgian Mastiff  Belgium and the Netherlands
#
#                                                  Url  \
# 0  https://en.wikipedia.org/wiki/Old_English_Terrier
# 1  https://en.wikipedia.org/wiki/Abyssinian_sand_...
# 2               https://en.wikipedia.org/wiki/Alaunt
# 3       https://en.wikipedia.org/wiki/Alpine_Mastiff
# 4      https://en.wikipedia.org/wiki/Belgian_Mastiff
#
#                                                  Img
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...
